# %%
saving_account,salary_account= input ("the number of saving_account and salary_account").split()
print("no of salary account:",saving_account)
print("no of saving account:",salary_account)
# Out:
# no of salary account: 300
# no of saving account: 400
